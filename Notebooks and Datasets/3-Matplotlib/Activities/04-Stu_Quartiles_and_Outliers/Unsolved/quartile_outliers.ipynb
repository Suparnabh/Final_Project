# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
from stats import median
import numpy as np
import seaborn as sns

# %%
### Data Points
arr = np.array([2.3, 10.2,11.2, 12.3, 14.5, 14.6, 15.0, 15.1, 19.0, 24.0])
arr
# Out:
# array([ 2.3, 10.2, 11.2, 12.3, 14.5, 14.6, 15. , 15.1, 19. , 24. ])

# %%
# Find the median
np.percentile(arr, 50)
# Out:
# 14.55

# %%
median(arr)
# Out:
# 14.55

# %%
# Use numpy to create quartiles
# lower quartile
q1 =np.percentile(arr, 25)

# %%
# Use numpy to create quartiles
# upper quartile
q3 = np.percentile(arr, 75)

# %%
# Print the quartiles
print(quartiles {} - {}'.format()')

# %%
# Calculate the interquartile range
iqr = q3 - q1
iqr
# Out:
# 3.6000000000000014

# %%
# Find lower boundary
# Q1 - 1.5 * IQR
lo_cutoff = q1 - 1.5*iqr
lo_cutoff
# Out:
# 6.074999999999996

# %%
# Find upper boundary
# Q3 + 1.5 * IQR
up_cutoff = q3 + 1.5*iqr
up_cutoff
# Out:
# 20.475

# %%
arr < lo_cutoff
# Out:
# array([ True, False, False, False, False, False, False, False, False,
#        False])

# %%
# Check for any lower outliers
arr[arr < lo_cutoff]
# Out:
# array([2.3])

# %%
# Check for any upper outliers
arr[arr > up_cutoff]
# Out:
# array([24.])

# %%
# Create box plot

# %%
plt.boxplot(arr)
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a2a039e50>,
#   <matplotlib.lines.Line2D at 0x1a29fb1dd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a2a14b8d0>,
#   <matplotlib.lines.Line2D at 0x1a2a14bdd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a2a039250>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a2a039f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a2a157850>],
#  'means': []}

# %%
sns.violinplot(y=arr)
